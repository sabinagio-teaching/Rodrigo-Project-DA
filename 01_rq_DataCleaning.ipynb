# %% [markdown]
# ----------------------------------------------------------------
#  DATA CLEANING
# ----------------------------------------------------------------
# ----------------------------------------------------------------

# %%
# Install to run code in notebook

# !pip install plotly.express
# !pip install meteostat
# Out:
# Requirement already satisfied: plotly.express in /opt/miniconda3/lib/python3.13/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in /opt/miniconda3/lib/python3.13/site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: plotly>=4.1.0 in /opt/miniconda3/lib/python3.13/site-packages (from plotly.express) (6.4.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/miniconda3/lib/python3.13/site-packages (from plotly.express) (0.14.5)
# Requirement already satisfied: scipy>=0.18 in /opt/miniconda3/lib/python3.13/site-packages (from plotly.express) (1.16.3)
# Requirement already satisfied: patsy>=0.5 in /opt/miniconda3/lib/python3.13/site-packages (from plotly.express) (1.0.2)
# Requirement already satisfied: numpy>=1.11 in /opt/miniconda3/lib/python3.13/site-packages (from plotly.express) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/lib/python3.13/site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/lib/python3.13/site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/lib/python3.13/site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/miniconda3/lib/python3.13/site-packages (from plotly>=4.1.0->plotly.express) (2.10.2)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.13/site-packages (from plotly>=4.1.0->plotly.express) (25.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.17.0)
# Requirement already satisfied: meteostat in /opt/miniconda3/lib/python3.13/site-packages (1.7.6)
# Requirement already satisfied: pandas>=2 in /opt/miniconda3/lib/python3.13/site-packages (from meteostat) (2.3.3)
# Requirement already satisfied: pytz in /opt/miniconda3/lib/python3.13/site-packages (from meteostat) (2025.2)
# Requirement already satisfied: numpy in /opt/miniconda3/lib/python3.13/site-packages (from meteostat) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/lib/python3.13/site-packages (from pandas>=2->meteostat) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/lib/python3.13/site-packages (from pandas>=2->meteostat) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2->meteostat) (1.17.0)

# %%
# Libraries used for data cleaning

import pandas as pd

# %%
df = pd.read_excel("../data/raw/GSAF5.xls")
df.head()
# Out:
#              Date    Year        Type     Country                  State  \
# 0    14th October  2025.0  Unprovoked    Columbia   Bolivar, del Isolate
# 1    11th October  2025.0  Unprovoked   Australia             Queensland
# 2     7th October  2025.0  Unprovoked   Australia        South Australia
# 3  29th September  2025.0  Unprovoked         USA         Off California
# 4  27th September  2025.0    Provoked  Costa Rica                    NaN
#
#                          Location               Activity                Name  \
# 0               Catagena Province   Swimming with sharks          Male child
# 1  Cook Esplanade Thursday Island       Fishing/swimming          Samuel Nai
# 2                 Kangaroo Island                Surfing        Lee Berryman
# 3                 Catalina Island               Swimming  Christopher Murray
# 4                   Cocos Islands  Diving-Tagging sharks  Dr. Mauricio Hoyos
#
#   Sex  Age  ...             Species   \
# 0   M   14  ...         Nurse shark
# 1   M   14  ...  Tiger or Bull shark
# 2   M  50+  ...       Bronze whaler?
# 3   M   54  ...   unknown 1.2m shark
# 4   M   48  ...       Tiger shark 4m
#
#                                           Source  pdf href formula href  \
# 0  Kevin McMurray Trackingsharks.com Andy Currie  NaN          NaN  NaN
# 1              Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 2              Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 3  Todd Smith: Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 4  Todd Smith: Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
#
#   Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN            NaN         NaN         NaN
# 1         NaN           NaN            NaN         NaN         NaN
# 2         NaN           NaN            NaN         NaN         NaN
# 3         NaN           NaN            NaN         NaN         NaN
# 4         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Injury Cleaning

# %%
df['Injury'].value_counts() 
# - Must clean Injury in to 2 answears only, 'yes' or 'no'.
# Out:
# Injury
# FATAL                                                                                                     863
# Foot bitten                                                                                               100
# Survived                                                                                                   97
# No injury                                                                                                  85
# Leg bitten                                                                                                 81
#                                                                                                          ...
# "Lost leg"                                                                                                  1
# FATAL, body not recovered but shark was caught with the man's loincloth in its gut shortly afterwards.      1
# FATAL, leg stripped of flesh                                                                                1
# FATAL, knocked overboard by tail of shark & carried off by shark                                            1
# Serious abdonminal injuries                                                                                 1
# Name: count, Length: 4167, dtype: int64

# %%
# - Injury column cleaning and classification
# - Replacing all types of injuries with these new classes we create from the coresponding values 
# we had before in Injury column:

df['Injury'] = df['Injury'].fillna('Unknown').astype(str).str.lower().str.strip()


def classify_injury(text):
    text = str(text).lower().strip()

    # Clear 'no injury' cases
    if any(word in text for word in ['no injury', 'uninjured','unharmed', 'none']):
        return 'No Injury'

    # If survived or recovered, do NOT count as fatal
    if any(word in text for word in ['survived', 'recovered', 'escaped', 'rescued', 'lived']):
        return 'Severe Wounds'

    # Fatal cases
    if any(word in text for word in [
        'body not recovered', 'fatal', 'died', 'death', 'deceased',
        'human remains', 'presumed dead'
    ]):
        return 'Fatal Wounds'

    # Minor cases
    if any(word in text for word in [
        'minor', 'scratch', 'abrasion', 'bruise', 'small', 'superficial', 'cut'
    ]):
        return 'Minor Wounds'

    # Severe cases
    if any(word in text for word in [
        'amputation', 'severe', 'major', 'deep', 'critical', 'massive',
        'laceration', 'bite', 'injured', 'tissue loss'
    ]):
        return 'Severe Wounds'

    return 'Unknown'
df['Injury_Class'] = df['Injury'].apply(classify_injury)

# %%
df['Injury_Class'].value_counts() 
# - Achieved less then 10% of unknowns in Injury_Class column
# - Some injury tipes could not be classified, this is because the reports are to vague in some cases so 
# we set it to unknown.
# Out:
# Injury_Class
# Unknown          2463
# Severe Wounds    1736
# Fatal Wounds     1435
# No Injury         884
# Minor Wounds      532
# Name: count, dtype: int64

# %% [markdown]
# ## Fatal Cleaning

# %%
# Fatal Y/N column cleaning

df['Fatal Y/N'] = df['Fatal Y/N'].astype(str).str.strip().str.upper()

df['Fatal Y/N'] = df['Fatal Y/N'].replace({
    'UNKNOWN': 'N',  
    'F': 'N',
    'M': 'N',
    'NAN': 'N',
    'NQ': 'N',
    '2017': 'N',
    'Y X 2': 'Y',
})

# - Since the shark attack report claims to only have fatal and non fatal attacks, 
# we will consider all unknowns as non-fatal for the purpose of this analysis.

# %%
df['Fatal Y/N'].value_counts(dropna=False) # We achieved less then 10% of unknowns in Fatal Y/N column
# Out:
# Fatal Y/N
# N    5566
# Y    1484
# Name: count, dtype: int64
