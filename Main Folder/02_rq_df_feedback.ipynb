# %% [markdown]
# ------------------------------------------------------------------------------------------------
# # DataFrames - Luxury Package
# ------------------------------------------------------------------------------------------------

# %%
import requests
import pandas as pd
import os
from dotenv import load_dotenv, find_dotenv
import time

# %% [markdown]
# ## Lisbon Hotels

# %%
df_hotels = pd.read_csv("lisbon_hotels.csv")
df_hotels.head(10)
# Out:
#    location_id                                        name  rating  \
# 0      2292067                           Czar Lisbon Hotel     3.7
# 1       206890        Avani Avenida Liberdade Lisbon Hotel     4.3
# 2     11600027                         Empire Lisbon Hotel     4.3
# 3      8842153  Palacio Do Governador - Lisbon Hotel & Spa     4.4
# 4     19780664    Aroeira Lisbon Hotel - Sea & Golf Resort     4.1
# 5       553361             Dinya Lisbon Hotel & Lounge Bar     4.3
# 6       781013                      New Style Lisbon Hotel     3.6
# 7     12659702         Corpo Santo Lisbon Historical Hotel     4.9
# 8     13402042                              Hotel Da Baixa     4.9
# 9       195643                        Hotel Avenida Palace     4.8
#
#    num_reviews  ranking price_level                      street1     city  \
# 0          947      NaN          $$   Avenida Almirante Reis 103   Lisbon
# 1          796      NaN         $$$  Rua Julio Cesar Machado 7 9   Lisbon
# 2          398      NaN          $$   Avenida Almirante Reis 130   Lisbon
# 3          526      NaN         $$$     Rua Bartolomeu Dias, 117   Lisbon
# 4           93      NaN          $$  Avenida Pinhal da Aroeira 1  Aroeira
# 5           34      NaN          $$           Rua Ilha do Pico 3   Lisbon
# 6           97      NaN          $$    Avenida Almirante Reis 53   Lisbon
# 7         4398      NaN        $$$$     Largo do Corpo Santo, 25   Lisbon
# 8         2868      NaN         $$$             Rua da Prata 231   Lisbon
# 9         5028      NaN        $$$$           Rua 1 Dezembro 123   Lisbon
#
#     country postalcode                                     address_string
# 0  Portugal  1150-0020  Avenida Almirante Reis 103, Lisbon 1150-0020 P...
# 1  Portugal   1250-135  Rua Julio Cesar Machado 7 9, Lisbon 1250-135 P...
# 2  Portugal   1150-023  Avenida Almirante Reis 130, Lisbon 1150-023 Po...
# 3  Portugal   1400-030  Rua Bartolomeu Dias, 117, Lisbon 1400-030 Port...
# 4  Portugal   2820-112  Avenida Pinhal da Aroeira 1 Herdade da Aroeira...
# 5  Portugal   1000-169       Rua Ilha do Pico 3, Lisbon 1000-169 Portugal
# 6  Portugal   1150-011  Avenida Almirante Reis 53, Lisbon 1150-011 Por...
# 7  Portugal   1200-129  Largo do Corpo Santo, 25, Lisbon 1200-129 Port...
# 8  Portugal   1100-417         Rua da Prata 231, Lisbon 1100-417 Portugal
# 9  Portugal   1200-359       Rua 1 Dezembro 123, Lisbon 1200-359 Portugal

# %% [markdown]
# Cleaning hotels by city and address to make sure we only get Lisbon hotels

# %%
df_hotels['city'].value_counts()
# Out:
# city
# Lisbon      46
# Aroeira      1
# Brooklyn     1
# Name: count, dtype: int64

# %%
df_hotels = df_hotels[df_hotels["address_string"].str.contains("Lisbon", case=False, na=False)]

# %%
df_hotels.drop(columns=["ranking"], inplace=True) # Removing the ranking column because it is empty.

# %% [markdown]
# ### Luxury Hotels:

# %%
# Step 1: filter the most expensive
df_lux_h = df_hotels[df_hotels["price_level"] == "$$$$"]

# Step 2: sort expensive ones by rating & reviews
df_lux_h_sorted = df_lux_h.sort_values(
    by=["rating", "num_reviews"],
    ascending=False
)

df_lux_h
# Out:
#     location_id                                               name  rating  \
# 7      12659702                Corpo Santo Lisbon Historical Hotel     4.9
# 9        195643                               Hotel Avenida Palace     4.8
# 12     10621974              Martinhal Lisbon Chiado Family Suites     4.9
# 13       231476                     InterContinental Lisbon by IHG     4.4
# 15      6351445                                Torel Palace Lisbon     4.7
# 16     23799173                               Hyatt Regency Lisbon     4.4
# 17      7376234                Santiago De Alfama - Boutique Hotel     4.9
# 21       548451                                  Bairro Alto Hotel     4.7
# 24       195742  Hotel Britania Art Deco, a Lisbon Heritage Col...     4.8
# 26       229311                     Four Seasons Hotel Ritz Lisbon     4.6
# 29     20313551                                    The Ivens Hotel     4.8
#
#     num_reviews price_level                    street1    city   country  \
# 7          4398        $$$$   Largo do Corpo Santo, 25  Lisbon  Portugal
# 9          5028        $$$$         Rua 1 Dezembro 123  Lisbon  Portugal
# 12          662        $$$$          Rua das Flores 44  Lisbon  Portugal
# 13          341        $$$$           Rua Castilho 149  Lisbon  Portugal
# 15         1093        $$$$     Rua Camara Pestana, 45  Lisbon  Portugal
# 16          515        $$$$        Rua da Junqueira 65  Lisbon  Portugal
# 17         1639        $$$$         Rua Santiago 10 14  Lisbon  Portugal
# 21         1715        $$$$     Praca Luis de Camoes 2  Lisbon  Portugal
# 24         3427        $$$$   Rua Rodrigues Sampaio 17  Lisbon  Portugal
# 26         2249        $$$$  Rua Rodrigo da Fonseca 88  Lisbon  Portugal
# 29          439        $$$$               Rua Capelo 5  Lisbon  Portugal
#
#    postalcode                                     address_string
# 7    1200-129  Largo do Corpo Santo, 25, Lisbon 1200-129 Port...
# 9    1200-359       Rua 1 Dezembro 123, Lisbon 1200-359 Portugal
# 12   1200-195        Rua das Flores 44, Lisbon 1200-195 Portugal
# 13   1099-034  Rua Castilho 149 Next to Parque Eduardo VII, L...
# 15   1150-082   Rua Camara Pestana, 45, Lisbon 1150-082 Portugal
# 16   1300-343      Rua da Junqueira 65, Lisbon 1300-343 Portugal
# 17   1100-494       Rua Santiago 10 14, Lisbon 1100-494 Portugal
# 21   1200-243   Praca Luis de Camoes 2, Lisbon 1200-243 Portugal
# 24   1150-278  Rua Rodrigues Sampaio 17, Lisbon 1150-278 Port...
# 26   1099-039  Rua Rodrigo da Fonseca 88, Lisbon 1099-039 Por...
# 29   1200-224             Rua Capelo 5, Lisbon 1200-224 Portugal

# %% [markdown]
# ---------------------------------------------------
# ## Lisbon Restaurants
# ------------------------------------------------

# %%
df_r = pd.read_csv("lisbon_restaurants.csv")
df_r.head(10)
# Out:
#    location_id                             name  rating  num_reviews  ranking  \
# 0     12516582     Love Lisbon Restaurant & Bar     4.1           44      NaN
# 1      4974326         Madrid Lisbon Restaurant     4.8            4      NaN
# 2      1520116          Floresta Das Escadinhas     4.8         7099      NaN
# 3      2308921                  Frade dos Mares     4.8         5546      NaN
# 4      1886758        Restaurant Ze da Mouraria     4.3          651      NaN
# 5     23976748                 Restaurant Odaan     4.9          742      NaN
# 6     13071752                         Jam Club     4.9         1757      NaN
# 7     15084159            #Treestory Restaurant     4.4          234      NaN
# 8      1721696  Come Prima Restaurante Italiano     4.8         4357      NaN
# 9     15087513                     A Nossa Casa     4.8         1489      NaN
#
#   price_level                                            cuisine  \
# 0    $$ - $$$                                 bar, asian, nepali
# 1    $$ - $$$                      european, spanish, portuguese
# 2           $  mediterranean, barbecue, european, healthy, po...
# 3    $$ - $$$       seafood, mediterranean, european, portuguese
# 4    $$ - $$$                mediterranean, european, portuguese
# 5           $                         indian, bar, asian, nepali
# 6           $                 portuguese, gastropub, dining_bars
# 7    $$ - $$$                 european, grill, georgian, healthy
# 8    $$ - $$$  italian, pizza, mediterranean, healthy, neapol...
# 9    $$ - $$$                              brazilian, portuguese
#
#                            street1    city        country  postalcode  \
# 0  R. Jose Antonio Serrano Floor 4  Lisbon       Portugal    1150-033
# 1                 325 Lafayette St  Newark  United States  07105-2724
# 2           Rua de Santa Justa N_3  Lisbon       Portugal    1100-483
# 3             Av. Dom Carlos I 55A  Lisbon       Portugal    1200-647
# 4           Rua Joao do Outeiro 24  Lisbon       Portugal    1100-292
# 5      Rua dos Cavaleiros 07 LJ 11  Lisbon       Portugal    1100-295
# 6      Travessa dos Inglesinhos 49  Lisbon       Portugal    1200-223
# 7         Rua Luciano Cordeiro 46A  Lisbon       Portugal    1150-216
# 8                Rua do Olival 256  Lisbon       Portugal    1200-744
# 9             Rua da Atalaia No 31  Lisbon       Portugal    1200-037
#
#                                       address_string
# 0  R. Jose Antonio Serrano Floor 4, Lisbon 1150-0...
# 1            325 Lafayette St, Newark, NJ 07105-2724
# 2   Rua de Santa Justa N_3, Lisbon 1100-483 Portugal
# 3     Av. Dom Carlos I 55A, Lisbon 1200-647 Portugal
# 4   Rua Joao do Outeiro 24, Lisbon 1100-292 Portugal
# 5  Rua dos Cavaleiros 07 LJ 11, Lisbon 1100-295 P...
# 6  Travessa dos Inglesinhos 49, Lisbon 1200-223 P...
# 7  Rua Luciano Cordeiro 46A, Lisbon 1150-216 Port...
# 8        Rua do Olival 256, Lisbon 1200-744 Portugal
# 9     Rua da Atalaia No 31, Lisbon 1200-037 Portugal

# %%
df_r['city'].value_counts()
# Out:
# city
# Lisbon         56
# Newark          1
# Jericho         1
# Carle Place     1
# Mineola         1
# La Oroya        1
# Addis Ababa     1
# Name: count, dtype: int64

# %% [markdown]
#  - API fetched restaurants outside of Lisbon because their name or description contains “Lisbon”.
#  - So I must clean this to only have restaurants situated in Lisbon.

# %%
df_r = df_r[df_r["address_string"].str.contains("Lisbon", case=False, na=False)]

# %%
df_r['city'].value_counts()
# Out:
# city
# Lisbon    56
# Name: count, dtype: int64

# %%
df_r.drop(columns=["ranking"], inplace=True) # Removing the ranking column because it is empty.

# %% [markdown]
# ### Luxury Restaurants

# %%
# Step 1: filter the most expensive
df_expensive = df_r[df_r["price_level"] == "$$$$"]

# Step 2: sort expensive ones by rating & reviews
df_expensive_sorted = df_expensive.sort_values(
    by=["rating", "num_reviews"],
    ascending=False
)

# I only have 7 restaurants with $$$$ price, we need extra restaurants:
num_missing = 10 - len(df_expensive_sorted)

if num_missing > 0:
    # Taking additional high-rated restaurants from the next tier $$ - $$$
    df_medium = df_r[df_r["price_level"] == "$$ - $$$"]
    
    df_medium_sorted = df_medium.sort_values(
        by=["rating", "num_reviews"],
        ascending=False
    ).head(num_missing)
    
    # Combining into final Luxury Restaurants
    df_r_luxury = pd.concat([df_expensive_sorted, df_medium_sorted])

else:
    df_r_luxury = df_expensive_sorted.head(10)

df_r_luxury
# Out:
#     location_id                         name  rating  num_reviews price_level  \
# 42     17443651                     Grenache     4.7          271        $$$$
# 46     15227438              Sala De Joao Sa     4.7          265        $$$$
# 40      2628518                     Belcanto     4.6         2248        $$$$
# 41      9977670      Alma Henrique Sa Pessoa     4.6         1155        $$$$
# 11      1058428          Solar dos Presuntos     4.3         6553        $$$$
# 23     12274149              JNcQUOI Avenida     4.3         1285        $$$$
# 44       878558            Eleven Restaurant     4.0         1227        $$$$
# 34     23808782        Seventh Brunch Chiado     4.9         1153    $$ - $$$
# 53     23691818  Sto Restaurante & Mercearia     4.9         1006    $$ - $$$
# 20     18942434              Antikuario Cafe     4.9          746    $$ - $$$
#
#                                               cuisine  \
# 42  french, mediterranean, european, international...
# 46       mediterranean, european, healthy, portuguese
# 40                           portuguese, contemporary
# 41  mediterranean, european, portuguese, contemporary
# 11  seafood, mediterranean, european, portuguese, ...
# 23                               european, portuguese
# 44  international, mediterranean, european, portug...
# 34  european, british, portuguese, cafe, internati...
# 53                                         portuguese
# 20       mediterranean, european, healthy, portuguese
#
#                              street1    city   country postalcode  \
# 42          12 patio de dom Fradique  Lisbon  Portugal   1120-624
# 46          Rua dos Bacalhoeiros 103  Lisbon  Portugal   1100-074
# 40               Rua Serpa Pinto 10A  Lisbon  Portugal   1200-410
# 41                   Rua Anchieta 15  Lisbon  Portugal   1200-023
# 11  Rua das Portas de Sto Antao, 150  Lisbon  Portugal   1150-269
# 23      Avenida Da Liberdade 182-184  Lisbon  Portugal   1250-146
# 44          Rua Marques de Fronteira  Lisbon  Portugal       1070
# 34             Calcada Do Combro 147  Lisbon  Portugal   1200-452
# 53            Rua dos Fanqueiros, 85  Lisbon  Portugal   1100-227
# 20               Rua de Sao Jose 168  Lisbon  Portugal   1150-326
#
#                                        address_string
# 42  12 patio de dom Fradique, Lisbon 1120-624 Port...
# 46  Rua dos Bacalhoeiros 103, Lisbon 1100-074 Port...
# 40      Rua Serpa Pinto 10A, Lisbon 1200-410 Portugal
# 41   Rua Anchieta 15 Chiado, Lisbon 1200-023 Portugal
# 11  Rua das Portas de Sto Antao, 150, Lisbon 1150-...
# 23  Avenida Da Liberdade 182-184 Tivoli Forum, Lis...
# 44  Rua Marques de Fronteira Jardim Amália Rodrigu...
# 34    Calcada Do Combro 147, Lisbon 1200-452 Portugal
# 53   Rua dos Fanqueiros, 85, Lisbon 1100-227 Portugal
# 20      Rua de Sao Jose 168, Lisbon 1150-326 Portugal

# %% [markdown]
# - Made Luxury Package for restaurants called "df_r_luxury", will use it to merge in to the other luxury DataFrames for final Luxury Package.

# %% [markdown]
# ------------------------------------------
# ## Lisbon Attractions
# --------------------------------------------

# %%
df_a = pd.read_csv("lisbon_attractions.csv")
df_a.head()
# Out:
#    location_id                                  name  rating  num_reviews  \
# 0       195107                  Castelo De Sao Jorge     4.2        30905
# 1       546590                     Parque Das Nacoes     4.3         4582
# 2     23804944                      Lisbon Cathedral     4.0         2167
# 3       199878  Praca do Comercio (Terreiro do Paco)     4.4        17271
# 4     23957745  Quake - Museu do Terramoto de Lisboa     4.6          939
#
#    ranking    category                      subcategory  \
# 0      NaN  attraction           landmarks, attractions
# 1      NaN  attraction    landmarks, attractions, other
# 2      NaN  attraction           landmarks, attractions
# 3      NaN  attraction           landmarks, attractions
# 4      NaN  attraction  landmarks, attractions, museums
#
#                            street1    city   country postalcode  \
# 0     Rua de Santa Cruz do Castelo  Lisbon  Portugal   1100-129
# 1          Avenida Dom Joao II 13B  Lisbon  Portugal   1990-998
# 2                    Largo da Se 1  Lisbon  Portugal   1100-585
# 3  Avenida Infante Dom Henrique 1C  Lisbon  Portugal   1100-053
# 4  Rua Cais da Alfandega Velha, 39  Lisbon  Portugal   1300-598
#
#                                       address_string
# 0  Rua de Santa Cruz do Castelo, Lisbon 1100-129 ...
# 1  Avenida Dom Joao II 13B, Lisbon 1990-998 Portugal
# 2            Largo da Se 1, Lisbon 1100-585 Portugal
# 3  Avenida Infante Dom Henrique 1C, Lisbon 1100-0...
# 4  Rua Cais da Alfandega Velha, 39, Lisbon 1300-5...

# %%
df_a['ranking'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# Name: ranking, Length: 70, dtype: float64>

# %%
df_a.drop(columns=['ranking'], inplace=True) # Droping ranking columns

# %% [markdown]
# - Attractions has no 'price' column like hotels or restaurants,
# so I will make the luxury attractions data set based on premium experiences such as:
#         - Boat Tours
#         - Private sightseeing Tours
#         - Gourmet food & wine tasting
#         - Spa & wellness
#         - Exclusive nightlife
#         - Art
#         - Shopping
# - Water activities seems a good subcategory for this list but it is an unstable subcategory for luxury due to weather dependent so we will focus only on the above.
# - Boat Tours are also a bit weather dependent but still doable.
#
# SABINA COMMENT: Really like these comments :)

# %% [markdown]
# --------------------------------------------------------------------------------
# ### Luxury Attractions

# %%
df_a['subcategory'].unique() # For my goal, subcategory column is to vague and icludes to much on the same row.
# Out:
# array(['landmarks, attractions', 'landmarks, attractions, other',
#        'landmarks, attractions, museums', 'nature_parks, attractions',
#        'museums, attractions',
#        'nature_parks, zoos_aquariums, attractions',
#        'transportation, attractions',
#        'sightseeing_tours, activities, outdoor_activities',
#        'shopping, museums, attractions',
#        'food_drink, sightseeing_tours, activities',
#        'boat_tours_water_sports, outdoor_activities, sightseeing_tours, activities',
#        'nightlife, sightseeing_tours, activities',
#        'sightseeing_tours, activities', 'nightlife',
#        'food_drink, landmarks, attractions, classes, activities',
#        'wellness_spas, activities',
#        'landmarks, attractions, sightseeing_tours, activities',
#        'shopping', 'fun_games, nature_parks, attractions, activities'],
#       dtype=object)

# %%
df_a['subcategory'].value_counts()
# Out:
# subcategory
# landmarks, attractions                                                        22
# museums, attractions                                                           7
# sightseeing_tours, activities                                                  6
# food_drink, sightseeing_tours, activities                                      5
# sightseeing_tours, activities, outdoor_activities                              5
# boat_tours_water_sports, outdoor_activities, sightseeing_tours, activities     4
# transportation, attractions                                                    4
# landmarks, attractions, museums                                                3
# shopping                                                                       2
# nightlife                                                                      2
# nature_parks, attractions                                                      2
# landmarks, attractions, other                                                  1
# nature_parks, zoos_aquariums, attractions                                      1
# shopping, museums, attractions                                                 1
# nightlife, sightseeing_tours, activities                                       1
# food_drink, landmarks, attractions, classes, activities                        1
# wellness_spas, activities                                                      1
# landmarks, attractions, sightseeing_tours, activities                          1
# fun_games, nature_parks, attractions, activities                               1
# Name: count, dtype: int64

# %%
df_a['tags'] = df_a['subcategory'].str.split(', ') # getting tags column for more specific data.

# %%
df_a_tags = df_a.explode('tags') # Getting seperate tags in each row.

# %%
df_a_tags['tags'].value_counts()
# Out:
# tags
# attractions                44
# landmarks                  28
# activities                 25
# sightseeing_tours          22
# museums                    11
# outdoor_activities          9
# food_drink                  6
# transportation              4
# nature_parks                4
# boat_tours_water_sports     4
# shopping                    3
# nightlife                   3
# other                       1
# zoos_aquariums              1
# classes                     1
# wellness_spas               1
# fun_games                   1
# Name: count, dtype: int64

# %%
df_a_tags[df_a_tags['tags'] == 'transportation'] # Transportation data is useless for luxury, weakness of the project.
# Out:
#     location_id                          name  rating  num_reviews  \
# 13       262792                       Tram 28     3.9        25138
# 33       546613  Carris - Eletricos de Lisboa     4.3         2654
# 36     10634885        Sintra Tourist Bus 434     2.2          625
# 42      9792343         Lisbon Airport travel     2.1          405
#
#       category                  subcategory street1    city   country  \
# 13  attraction  transportation, attractions     NaN  Lisbon  Portugal
# 33  attraction  transportation, attractions     NaN  Lisbon  Portugal
# 36  attraction  transportation, attractions     NaN  Sintra  Portugal
# 42  attraction  transportation, attractions     NaN  Lisbon  Portugal
#
#    postalcode            address_string            tags
# 13        NaN           Lisbon Portugal  transportation
# 33   2795-221  Lisbon 2795-221 Portugal  transportation
# 36   2645-019  Sintra 2645-019 Portugal  transportation
# 42        NaN           Lisbon Portugal  transportation

# %% [markdown]
# I consider transportation a weakness of the project due to lack of data, we only have city public transports such has bus, tram and cables cars.
# TripAdvisor API endpoint doesnt give data of private high-end companies that offer a more luxurious service.

# %% [markdown]
# The strongest categories for a luxury product are:
#
# * Wellness Spas:
#
#     Ultra-premium category
#
#     Very high rating (4.90)
#
#     Ideal for luxury packages:
#
# * Outdoor Activities:
#
#     Rating almost 5.0
#
#     Usually small-group, curated, premium experiences
#
# * Boat Tours & Water Sports:
#
#     Premium boat tours, private yachts, sunset cruises
#
# * Food & Drink (wine tastings, gourmet tours):
#
#     Often expensive
#
#     High quality (4.78)
#
# * High-end Sightseeing Tours:
#
#     Private guides
#
#     Small-group premium tours
#
# We can ignore the other tags since they are either family activities like nature_parks, zoos_aquariums or not luxury type at all like classes, fun_games etc.

# %%
# Creating a tag list for luxury attractions intended for luxury package
luxury_tags = [
    "wellness_spas",
    "outdoor_activities",
    "boat_tours_water_sports",
    "food_drink",
    "sightseeing_tours",
    "museums",
]

df_lux_a = df_a[
    df_a["tags"].apply(lambda tag_list: any(t in luxury_tags for t in tag_list))
]

df_lux_a.head(35)
# Out:
#     location_id                                            name  rating  \
# 4      23957745            Quake - Museu do Terramoto de Lisboa     4.6
# 7       3928986                             Lisboa Story Centre     4.2
# 12      2229331                        Pavilhao do Conhecimento     4.5
# 14      6628842                                 Bikes & Company     4.9
# 17       195776                            National Tile Museum     4.5
# 18       195106                      Calouste Gulbenkian Museum     4.6
# 19       195736                   Museu Nacional De Arte Antiga     4.5
# 20      1996418                     Museu Arqueologico do Carmo     4.4
# 21     24153846                           Royal Treasure Museum     4.7
# 22     12875410  National Museum of Natural History and Science     3.5
# 23      1973832                        Museu Medeiros E Almeida     4.7
# 25      1775700                           We Hate Tourism Tours     4.8
# 26      1746966                             Inside Lisbon Tours     4.8
# 28      4289715                                  Lisbon by Boat     4.9
# 29     10113758                                 Discover Lisbon     4.8
# 30     10686020                              Eco Tuk Tuk Lisbon     5.0
# 31      2021248                         City Sightseeing Lisbon     2.3
# 32      6124558         Lisbon Hop-on Hop-off Sightseeing Tours     2.2
# 34      8078675                                 My Lisbon Tours     4.9
# 35     12920370                                Lisbon with Pats     5.0
# 38      2169079                                Lisbon by Segway     4.9
# 40      3214902                          Time Out Market Lisboa     4.3
# 43      4187481              Lisbon4Smile Tourist Guides -Tours     5.0
# 46      8460163                               ColourTrip Lisbon     5.0
# 47     10807704                                      Nosso Tejo     4.8
# 48      7697318                               Tuk-Tuk Fun Tours     4.8
# 49      2412618       Rua dos Correeiros Archaeological Nucleus     4.6
# 50      3954222        Halcyon I - Historical Lisbon Boat Tours     4.9
# 52     15518965                               EcoMassage Lisbon     4.9
# 53      3203667                                   Around Lisbon     4.8
# 54      1823200                                Lisbon Bike Tour     4.9
# 55      2353620                Miradouro Sao Pedro de Alcantara     4.5
# 56      7374624                     Culinary Backstreets Lisbon     5.0
# 65     12258331                                  Cycling Lisbon     5.0
# 67      2043527                                   Lisbon Walker     4.8
#
#     num_reviews    category  \
# 4           939  attraction
# 7           932  attraction
# 12          958  attraction
# 14         1422  attraction
# 17         4597  attraction
# 18         8709  attraction
# 19         1329  attraction
# 20         2968  attraction
# 21          251  attraction
# 22          398  attraction
# 23          252  attraction
# 25         1817  attraction
# 26        11966  attraction
# 28         2033  attraction
# 29         5445  attraction
# 30         2152  attraction
# 31         1355  attraction
# 32         1288  attraction
# 34          716  attraction
# 35          167  attraction
# 38         1538  attraction
# 40        25050  attraction
# 43           63  attraction
# 46         2983  attraction
# 47         2734  attraction
# 48          382  attraction
# 49          150  attraction
# 50          281  attraction
# 52         1553  attraction
# 53         1546  attraction
# 54          785  attraction
# 55         3629  attraction
# 56         1727  attraction
# 65          165  attraction
# 67          409  attraction
#
#                                           subcategory  \
# 4                     landmarks, attractions, museums
# 7                                museums, attractions
# 12                               museums, attractions
# 14  sightseeing_tours, activities, outdoor_activities
# 17                               museums, attractions
# 18                     shopping, museums, attractions
# 19                               museums, attractions
# 20                               museums, attractions
# 21                    landmarks, attractions, museums
# 22                               museums, attractions
# 23                               museums, attractions
# 25          food_drink, sightseeing_tours, activities
# 26          food_drink, sightseeing_tours, activities
# 28  boat_tours_water_sports, outdoor_activities, s...
# 29           nightlife, sightseeing_tours, activities
# 30  sightseeing_tours, activities, outdoor_activities
# 31                      sightseeing_tours, activities
# 32                      sightseeing_tours, activities
# 34          food_drink, sightseeing_tours, activities
# 35                      sightseeing_tours, activities
# 38          food_drink, sightseeing_tours, activities
# 40  food_drink, landmarks, attractions, classes, a...
# 43                      sightseeing_tours, activities
# 46  sightseeing_tours, activities, outdoor_activities
# 47  boat_tours_water_sports, outdoor_activities, s...
# 48                      sightseeing_tours, activities
# 49                    landmarks, attractions, museums
# 50  boat_tours_water_sports, outdoor_activities, s...
# 52                          wellness_spas, activities
# 53  boat_tours_water_sports, outdoor_activities, s...
# 54  sightseeing_tours, activities, outdoor_activities
# 55  landmarks, attractions, sightseeing_tours, act...
# 56          food_drink, sightseeing_tours, activities
# 65  sightseeing_tours, activities, outdoor_activities
# 67                      sightseeing_tours, activities
#
#                                       street1    city   country postalcode  \
# 4             Rua Cais da Alfandega Velha, 39  Lisbon  Portugal   1300-598
# 7                    Terreiro do Paco, 78- 81  Lisbon  Portugal   1100-148
# 12               Largo Jose Mariano Gago N0 1  Lisbon  Portugal   1990-073
# 14                      Rua dos Douradores 16  Lisbon  Portugal   1100-206
# 17                        Rua Madre de Deus 4  Lisbon  Portugal   1900-312
# 18                       Avenida de Berna 45A  Lisbon  Portugal   1067-001
# 19                     Rua das Janelas Verdes  Lisbon  Portugal   1249-017
# 20                             Largo do Carmo  Lisbon  Portugal   1200-092
# 21                           Calcada da Ajuda  Lisbon  Portugal   1300-012
# 22            Rua da Escola Politecnica 56 58  Lisbon  Portugal   1250-102
# 23                         Rua Rosa Araujo 41  Lisbon  Portugal   1250-194
# 25                                        NaN  Lisbon  Portugal   1300-501
# 26                    Rua Ivone Silva 6 70ESQ  Lisbon  Portugal   1050-124
# 28  Padrao dos Descobrimentos , Doca de Belem  Lisbon  Portugal   1300-000
# 29                                        NaN  Lisbon  Portugal       1100
# 30                         Tv. do Carvalho 25  Lisbon  Portugal   1200-058
# 31                                        NaN  Lisbon  Portugal        NaN
# 32                                        NaN  Lisbon  Portugal   1070-051
# 34              Avenida Oscar Monteiro Torres  Lisbon  Portugal   1000-220
# 35                                        NaN  Lisbon  Portugal        NaN
# 38                      Rua dos Douradores 16  Lisbon  Portugal   1100-206
# 40                        Avenida 24 de Julho  Lisbon  Portugal   1200-479
# 43                          Largo do Carmo 18  Lisbon  Portugal   1200-092
# 46                                        NaN  Lisbon  Portugal        NaN
# 47                                        NaN  Lisbon  Portugal   1100-278
# 48                                        NaN  Lisbon  Portugal        NaN
# 49                   Rua dos Correeiros 15 23  Lisbon  Portugal   1100-161
# 50                Doca de Alcantara Norte 701  Lisbon  Portugal   1350-352
# 52                              Rua aurea 260  Lisbon  Portugal   1100-062
# 53                                        NaN  Lisbon  Portugal        NaN
# 54                  Alameda Cardeal Cerejeira  Lisbon  Portugal   1070-044
# 55              Rua De Sao Pedro De Alcantara  Lisbon  Portugal   1200-470
# 56                                        NaN  Lisbon  Portugal        NaN
# 65   Alto do Parque Alameda Cardeal Cerejeira  Lisbon  Portugal   1070-044
# 67            Rua do Jardim do Tabaco 126 Slj  Lisbon  Portugal   1100-288
#
#                                        address_string  \
# 4   Rua Cais da Alfandega Velha, 39, Lisbon 1300-5...
# 7   Terreiro do Paco, 78- 81, Lisbon 1100-148 Port...
# 12  Largo Jose Mariano Gago N0 1, Lisbon 1990-073 ...
# 14    Rua dos Douradores 16, Lisbon 1100-206 Portugal
# 17      Rua Madre de Deus 4, Lisbon 1900-312 Portugal
# 18     Avenida de Berna 45A, Lisbon 1067-001 Portugal
# 19   Rua das Janelas Verdes, Lisbon 1249-017 Portugal
# 20           Largo do Carmo, Lisbon 1200-092 Portugal
# 21  Calcada da Ajuda Ajuda National Palace, Lisbon...
# 22  Rua da Escola Politecnica 56 58, Lisbon 1250-1...
# 23       Rua Rosa Araujo 41, Lisbon 1250-194 Portugal
# 25                           Lisbon 1300-501 Portugal
# 26  Rua Ivone Silva 6 70ESQ, Lisbon 1050-124 Portugal
# 28  Padrao dos Descobrimentos , Doca de Belem, Lis...
# 29                               Lisbon 1100 Portugal
# 30       Tv. do Carvalho 25, Lisbon 1200-058 Portugal
# 31                                    Lisbon Portugal
# 32                           Lisbon 1070-051 Portugal
# 34  Avenida Oscar Monteiro Torres, Lisbon 1000-220...
# 35                                    Lisbon Portugal
# 38    Rua dos Douradores 16, Lisbon 1100-206 Portugal
# 40      Avenida 24 de Julho, Lisbon 1200-479 Portugal
# 43        Largo do Carmo 18, Lisbon 1200-092 Portugal
# 46                                    Lisbon Portugal
# 47                           Lisbon 1100-278 Portugal
# 48                                    Lisbon Portugal
# 49  Rua dos Correeiros 15 23, Lisbon 1100-161 Port...
# 50  Doca de Alcantara Norte 701, Lisbon 1350-352 P...
# 52  Rua aurea 260 Praça Rossio, Lisbon 1100-062 Po...
# 53                                    Lisbon Portugal
# 54  Alameda Cardeal Cerejeira, Lisbon 1070-044 Por...
# 55  Rua De Sao Pedro De Alcantara Jardim Dos Namor...
# 56                                    Lisbon Portugal
# 65  Alto do Parque Alameda Cardeal Cerejeira Park ...
# 67  Rua do Jardim do Tabaco 126 Slj, Lisbon 1100-2...
#
#                                                  tags
# 4                   [landmarks, attractions, museums]
# 7                              [museums, attractions]
# 12                             [museums, attractions]
# 14  [sightseeing_tours, activities, outdoor_activi...
# 17                             [museums, attractions]
# 18                   [shopping, museums, attractions]
# 19                             [museums, attractions]
# 20                             [museums, attractions]
# 21                  [landmarks, attractions, museums]
# 22                             [museums, attractions]
# 23                             [museums, attractions]
# 25        [food_drink, sightseeing_tours, activities]
# 26        [food_drink, sightseeing_tours, activities]
# 28  [boat_tours_water_sports, outdoor_activities, ...
# 29         [nightlife, sightseeing_tours, activities]
# 30  [sightseeing_tours, activities, outdoor_activi...
# 31                    [sightseeing_tours, activities]
# 32                    [sightseeing_tours, activities]
# 34        [food_drink, sightseeing_tours, activities]
# 35                    [sightseeing_tours, activities]
# 38        [food_drink, sightseeing_tours, activities]
# 40  [food_drink, landmarks, attractions, classes, ...
# 43                    [sightseeing_tours, activities]
# 46  [sightseeing_tours, activities, outdoor_activi...
# 47  [boat_tours_water_sports, outdoor_activities, ...
# 48                    [sightseeing_tours, activities]
# 49                  [landmarks, attractions, museums]
# 50  [boat_tours_water_sports, outdoor_activities, ...
# 52                        [wellness_spas, activities]
# 53  [boat_tours_water_sports, outdoor_activities, ...
# 54  [sightseeing_tours, activities, outdoor_activi...
# 55  [landmarks, attractions, sightseeing_tours, ac...
# 56        [food_drink, sightseeing_tours, activities]
# 65  [sightseeing_tours, activities, outdoor_activi...
# 67                    [sightseeing_tours, activities]

# %% [markdown]
# Since I have no prices on attractions, I will use a weightmap on the tags to add to review points and counts to decide which attractions fit into luxury package.

# %%
luxury_weights = {
    "wellness_spas": 10,
    "boat_tours_water_sports": 9,
    "food_drink": 8,
    "outdoor_activities": 7,
    "sightseeing_tours": 6,
    "museums": 4,
    "nightlife": 3,
    "shopping": 2,
    "landmarks": 1
}

def luxury_score(row):
    tags = row["tags"]
    
    # Tag luxury score = highest luxury weight among tags
    tag_score = max([luxury_weights.get(t, 0) for t in tags])
    
    rating = row.get("rating", 0)
    reviews = row.get("num_reviews", 0)
    
    score = (rating * 3) + (reviews * 0.001) + tag_score # Weighted luxury score formula
    
    return score

df_lux_a["luxury_score"] = df_lux_a.apply(luxury_score, axis=1)

df_luxury_attractions = df_lux_a.sort_values("luxury_score", ascending=False) # Sorting values
# Out:
# /var/folders/vf/s7r4l2kd6b9c4r8bzkttmr2h0000gp/T/ipykernel_1009/1135150111.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lux_a["luxury_score"] = df_lux_a.apply(luxury_score, axis=1)

# %%
df_luxury_attractions.head(20)
# Out:
#     location_id                                      name  rating  \
# 40      3214902                    Time Out Market Lisboa     4.3
# 26      1746966                       Inside Lisbon Tours     4.8
# 18       195106                Calouste Gulbenkian Museum     4.6
# 52     15518965                         EcoMassage Lisbon     4.9
# 47     10807704                                Nosso Tejo     4.8
# 29     10113758                           Discover Lisbon     4.8
# 28      4289715                            Lisbon by Boat     4.9
# 46      8460163                         ColourTrip Lisbon     5.0
# 53      3203667                             Around Lisbon     4.8
# 56      7374624               Culinary Backstreets Lisbon     5.0
# 38      2169079                          Lisbon by Segway     4.9
# 25      1775700                     We Hate Tourism Tours     4.8
# 30     10686020                        Eco Tuk Tuk Lisbon     5.0
# 50      3954222  Halcyon I - Historical Lisbon Boat Tours     4.9
# 34      8078675                           My Lisbon Tours     4.9
# 55      2353620          Miradouro Sao Pedro de Alcantara     4.5
# 14      6628842                           Bikes & Company     4.9
# 54      1823200                          Lisbon Bike Tour     4.9
# 65     12258331                            Cycling Lisbon     5.0
# 17       195776                      National Tile Museum     4.5
#
#     num_reviews    category  \
# 40        25050  attraction
# 26        11966  attraction
# 18         8709  attraction
# 52         1553  attraction
# 47         2734  attraction
# 29         5445  attraction
# 28         2033  attraction
# 46         2983  attraction
# 53         1546  attraction
# 56         1727  attraction
# 38         1538  attraction
# 25         1817  attraction
# 30         2152  attraction
# 50          281  attraction
# 34          716  attraction
# 55         3629  attraction
# 14         1422  attraction
# 54          785  attraction
# 65          165  attraction
# 17         4597  attraction
#
#                                           subcategory  \
# 40  food_drink, landmarks, attractions, classes, a...
# 26          food_drink, sightseeing_tours, activities
# 18                     shopping, museums, attractions
# 52                          wellness_spas, activities
# 47  boat_tours_water_sports, outdoor_activities, s...
# 29           nightlife, sightseeing_tours, activities
# 28  boat_tours_water_sports, outdoor_activities, s...
# 46  sightseeing_tours, activities, outdoor_activities
# 53  boat_tours_water_sports, outdoor_activities, s...
# 56          food_drink, sightseeing_tours, activities
# 38          food_drink, sightseeing_tours, activities
# 25          food_drink, sightseeing_tours, activities
# 30  sightseeing_tours, activities, outdoor_activities
# 50  boat_tours_water_sports, outdoor_activities, s...
# 34          food_drink, sightseeing_tours, activities
# 55  landmarks, attractions, sightseeing_tours, act...
# 14  sightseeing_tours, activities, outdoor_activities
# 54  sightseeing_tours, activities, outdoor_activities
# 65  sightseeing_tours, activities, outdoor_activities
# 17                               museums, attractions
#
#                                       street1    city   country postalcode  \
# 40                        Avenida 24 de Julho  Lisbon  Portugal   1200-479
# 26                    Rua Ivone Silva 6 70ESQ  Lisbon  Portugal   1050-124
# 18                       Avenida de Berna 45A  Lisbon  Portugal   1067-001
# 52                              Rua aurea 260  Lisbon  Portugal   1100-062
# 47                                        NaN  Lisbon  Portugal   1100-278
# 29                                        NaN  Lisbon  Portugal       1100
# 28  Padrao dos Descobrimentos , Doca de Belem  Lisbon  Portugal   1300-000
# 46                                        NaN  Lisbon  Portugal        NaN
# 53                                        NaN  Lisbon  Portugal        NaN
# 56                                        NaN  Lisbon  Portugal        NaN
# 38                      Rua dos Douradores 16  Lisbon  Portugal   1100-206
# 25                                        NaN  Lisbon  Portugal   1300-501
# 30                         Tv. do Carvalho 25  Lisbon  Portugal   1200-058
# 50                Doca de Alcantara Norte 701  Lisbon  Portugal   1350-352
# 34              Avenida Oscar Monteiro Torres  Lisbon  Portugal   1000-220
# 55              Rua De Sao Pedro De Alcantara  Lisbon  Portugal   1200-470
# 14                      Rua dos Douradores 16  Lisbon  Portugal   1100-206
# 54                  Alameda Cardeal Cerejeira  Lisbon  Portugal   1070-044
# 65   Alto do Parque Alameda Cardeal Cerejeira  Lisbon  Portugal   1070-044
# 17                        Rua Madre de Deus 4  Lisbon  Portugal   1900-312
#
#                                        address_string  \
# 40      Avenida 24 de Julho, Lisbon 1200-479 Portugal
# 26  Rua Ivone Silva 6 70ESQ, Lisbon 1050-124 Portugal
# 18     Avenida de Berna 45A, Lisbon 1067-001 Portugal
# 52  Rua aurea 260 Praça Rossio, Lisbon 1100-062 Po...
# 47                           Lisbon 1100-278 Portugal
# 29                               Lisbon 1100 Portugal
# 28  Padrao dos Descobrimentos , Doca de Belem, Lis...
# 46                                    Lisbon Portugal
# 53                                    Lisbon Portugal
# 56                                    Lisbon Portugal
# 38    Rua dos Douradores 16, Lisbon 1100-206 Portugal
# 25                           Lisbon 1300-501 Portugal
# 30       Tv. do Carvalho 25, Lisbon 1200-058 Portugal
# 50  Doca de Alcantara Norte 701, Lisbon 1350-352 P...
# 34  Avenida Oscar Monteiro Torres, Lisbon 1000-220...
# 55  Rua De Sao Pedro De Alcantara Jardim Dos Namor...
# 14    Rua dos Douradores 16, Lisbon 1100-206 Portugal
# 54  Alameda Cardeal Cerejeira, Lisbon 1070-044 Por...
# 65  Alto do Parque Alameda Cardeal Cerejeira Park ...
# 17      Rua Madre de Deus 4, Lisbon 1900-312 Portugal
#
#                                                  tags  luxury_score
# 40  [food_drink, landmarks, attractions, classes, ...        45.950
# 26        [food_drink, sightseeing_tours, activities]        34.366
# 18                   [shopping, museums, attractions]        26.509
# 52                        [wellness_spas, activities]        26.253
# 47  [boat_tours_water_sports, outdoor_activities, ...        26.134
# 29         [nightlife, sightseeing_tours, activities]        25.845
# 28  [boat_tours_water_sports, outdoor_activities, ...        25.733
# 46  [sightseeing_tours, activities, outdoor_activi...        24.983
# 53  [boat_tours_water_sports, outdoor_activities, ...        24.946
# 56        [food_drink, sightseeing_tours, activities]        24.727
# 38        [food_drink, sightseeing_tours, activities]        24.238
# 25        [food_drink, sightseeing_tours, activities]        24.217
# 30  [sightseeing_tours, activities, outdoor_activi...        24.152
# 50  [boat_tours_water_sports, outdoor_activities, ...        23.981
# 34        [food_drink, sightseeing_tours, activities]        23.416
# 55  [landmarks, attractions, sightseeing_tours, ac...        23.129
# 14  [sightseeing_tours, activities, outdoor_activi...        23.122
# 54  [sightseeing_tours, activities, outdoor_activi...        22.485
# 65  [sightseeing_tours, activities, outdoor_activi...        22.165
# 17                             [museums, attractions]        22.097

# %% [markdown]
# These are the attractions that are most fitted to luxury package from our analysis

# %%
# Saving luxury attractions df to csv file to analyze with visualizations:

df_luxury_attractions.to_csv("luxury_attractions.csv", index=False)

# %%
df_lux_a = df_lux_a.copy()
df_lux_a["luxury_score"] = df_lux_a.apply(luxury_score, axis=1)

# %% [markdown]
# choosing best 5 attractions for luxury:

# %%
top5_luxury_attractions = (
    df_lux_a.sort_values("luxury_score", ascending=False)
            .head(5)
            .reset_index(drop=True)
)

# %%
top5_luxury_attractions
# Out:
#    location_id                        name  rating  num_reviews    category  \
# 0      3214902      Time Out Market Lisboa     4.3        25050  attraction
# 1      1746966         Inside Lisbon Tours     4.8        11966  attraction
# 2       195106  Calouste Gulbenkian Museum     4.6         8709  attraction
# 3     15518965           EcoMassage Lisbon     4.9         1553  attraction
# 4     10807704                  Nosso Tejo     4.8         2734  attraction
#
#                                          subcategory                  street1  \
# 0  food_drink, landmarks, attractions, classes, a...      Avenida 24 de Julho
# 1          food_drink, sightseeing_tours, activities  Rua Ivone Silva 6 70ESQ
# 2                     shopping, museums, attractions     Avenida de Berna 45A
# 3                          wellness_spas, activities            Rua aurea 260
# 4  boat_tours_water_sports, outdoor_activities, s...                      NaN
#
#      city   country postalcode  \
# 0  Lisbon  Portugal   1200-479
# 1  Lisbon  Portugal   1050-124
# 2  Lisbon  Portugal   1067-001
# 3  Lisbon  Portugal   1100-062
# 4  Lisbon  Portugal   1100-278
#
#                                       address_string  \
# 0      Avenida 24 de Julho, Lisbon 1200-479 Portugal
# 1  Rua Ivone Silva 6 70ESQ, Lisbon 1050-124 Portugal
# 2     Avenida de Berna 45A, Lisbon 1067-001 Portugal
# 3  Rua aurea 260 Praça Rossio, Lisbon 1100-062 Po...
# 4                           Lisbon 1100-278 Portugal
#
#                                                 tags  luxury_score
# 0  [food_drink, landmarks, attractions, classes, ...        45.950
# 1        [food_drink, sightseeing_tours, activities]        34.366
# 2                   [shopping, museums, attractions]        26.509
# 3                        [wellness_spas, activities]        26.253
# 4  [boat_tours_water_sports, outdoor_activities, ...        26.134

# %% [markdown]
# ## Final Luxury Package

# %%
# Creating copys and adding category columns for final dataframe

df_lux_h = df_lux_h.copy()
df_lux_h["category"] = "Hotel"

df_r_luxury = df_r_luxury.copy()
df_r_luxury["category"] = "Restaurant"

top5_luxury_attractions= top5_luxury_attractions.copy()
top5_luxury_attractions["category"] = "Attraction"

# %%
# Concat and cleaning
luxury_package = pd.concat([
    df_lux_h.assign(category="Hotel"),
    df_r_luxury.assign(category="Restaurant"),
    top5_luxury_attractions.assign(category="Attraction")
], ignore_index=True)

luxury_package["price_level"] = luxury_package["price_level"].fillna("—")

# %%
# Getting 5 hotels only
lux_hotels = luxury_package[luxury_package["category"] == "Hotel"] \
    .sort_values(["rating", "num_reviews"], ascending=False) \
    .head(5)

lux_restaurants = luxury_package[luxury_package["category"] == "Restaurant"] \
    .sort_values(["rating", "num_reviews"], ascending=False) \
    .head(10) 

lux_attractions = luxury_package[luxury_package["category"] == "Attraction"]

# %%
# Concatenating in to final luxury package
final_luxury_package = pd.concat([lux_hotels, lux_restaurants, lux_attractions], ignore_index=True)
final_luxury_package # 20 items luxury package :)
# Out:
#     location_id                                               name  rating  \
# 0      12659702                Corpo Santo Lisbon Historical Hotel     4.9
# 1       7376234                Santiago De Alfama - Boutique Hotel     4.9
# 2      10621974              Martinhal Lisbon Chiado Family Suites     4.9
# 3        195643                               Hotel Avenida Palace     4.8
# 4        195742  Hotel Britania Art Deco, a Lisbon Heritage Col...     4.8
# 5      23808782                              Seventh Brunch Chiado     4.9
# 6      23691818                        Sto Restaurante & Mercearia     4.9
# 7      18942434                                    Antikuario Cafe     4.9
# 8      17443651                                           Grenache     4.7
# 9      15227438                                    Sala De Joao Sa     4.7
# 10      2628518                                           Belcanto     4.6
# 11      9977670                            Alma Henrique Sa Pessoa     4.6
# 12      1058428                                Solar dos Presuntos     4.3
# 13     12274149                                    JNcQUOI Avenida     4.3
# 14       878558                                  Eleven Restaurant     4.0
# 15      3214902                             Time Out Market Lisboa     4.3
# 16      1746966                                Inside Lisbon Tours     4.8
# 17       195106                         Calouste Gulbenkian Museum     4.6
# 18     15518965                                  EcoMassage Lisbon     4.9
# 19     10807704                                         Nosso Tejo     4.8
#
#     num_reviews price_level                           street1    city  \
# 0          4398        $$$$          Largo do Corpo Santo, 25  Lisbon
# 1          1639        $$$$                Rua Santiago 10 14  Lisbon
# 2           662        $$$$                 Rua das Flores 44  Lisbon
# 3          5028        $$$$                Rua 1 Dezembro 123  Lisbon
# 4          3427        $$$$          Rua Rodrigues Sampaio 17  Lisbon
# 5          1153    $$ - $$$             Calcada Do Combro 147  Lisbon
# 6          1006    $$ - $$$            Rua dos Fanqueiros, 85  Lisbon
# 7           746    $$ - $$$               Rua de Sao Jose 168  Lisbon
# 8           271        $$$$          12 patio de dom Fradique  Lisbon
# 9           265        $$$$          Rua dos Bacalhoeiros 103  Lisbon
# 10         2248        $$$$               Rua Serpa Pinto 10A  Lisbon
# 11         1155        $$$$                   Rua Anchieta 15  Lisbon
# 12         6553        $$$$  Rua das Portas de Sto Antao, 150  Lisbon
# 13         1285        $$$$      Avenida Da Liberdade 182-184  Lisbon
# 14         1227        $$$$          Rua Marques de Fronteira  Lisbon
# 15        25050           —               Avenida 24 de Julho  Lisbon
# 16        11966           —           Rua Ivone Silva 6 70ESQ  Lisbon
# 17         8709           —              Avenida de Berna 45A  Lisbon
# 18         1553           —                     Rua aurea 260  Lisbon
# 19         2734           —                               NaN  Lisbon
#
#      country postalcode                                     address_string  \
# 0   Portugal   1200-129  Largo do Corpo Santo, 25, Lisbon 1200-129 Port...
# 1   Portugal   1100-494       Rua Santiago 10 14, Lisbon 1100-494 Portugal
# 2   Portugal   1200-195        Rua das Flores 44, Lisbon 1200-195 Portugal
# 3   Portugal   1200-359       Rua 1 Dezembro 123, Lisbon 1200-359 Portugal
# 4   Portugal   1150-278  Rua Rodrigues Sampaio 17, Lisbon 1150-278 Port...
# 5   Portugal   1200-452    Calcada Do Combro 147, Lisbon 1200-452 Portugal
# 6   Portugal   1100-227   Rua dos Fanqueiros, 85, Lisbon 1100-227 Portugal
# 7   Portugal   1150-326      Rua de Sao Jose 168, Lisbon 1150-326 Portugal
# 8   Portugal   1120-624  12 patio de dom Fradique, Lisbon 1120-624 Port...
# 9   Portugal   1100-074  Rua dos Bacalhoeiros 103, Lisbon 1100-074 Port...
# 10  Portugal   1200-410      Rua Serpa Pinto 10A, Lisbon 1200-410 Portugal
# 11  Portugal   1200-023   Rua Anchieta 15 Chiado, Lisbon 1200-023 Portugal
# 12  Portugal   1150-269  Rua das Portas de Sto Antao, 150, Lisbon 1150-...
# 13  Portugal   1250-146  Avenida Da Liberdade 182-184 Tivoli Forum, Lis...
# 14  Portugal       1070  Rua Marques de Fronteira Jardim Amália Rodrigu...
# 15  Portugal   1200-479      Avenida 24 de Julho, Lisbon 1200-479 Portugal
# 16  Portugal   1050-124  Rua Ivone Silva 6 70ESQ, Lisbon 1050-124 Portugal
# 17  Portugal   1067-001     Avenida de Berna 45A, Lisbon 1067-001 Portugal
# 18  Portugal   1100-062  Rua aurea 260 Praça Rossio, Lisbon 1100-062 Po...
# 19  Portugal   1100-278                           Lisbon 1100-278 Portugal
#
#       category                                            cuisine  \
# 0        Hotel                                                NaN
# 1        Hotel                                                NaN
# 2        Hotel                                                NaN
# 3        Hotel                                                NaN
# 4        Hotel                                                NaN
# 5   Restaurant  european, british, portuguese, cafe, internati...
# 6   Restaurant                                         portuguese
# 7   Restaurant       mediterranean, european, healthy, portuguese
# 8   Restaurant  french, mediterranean, european, international...
# 9   Restaurant       mediterranean, european, healthy, portuguese
# 10  Restaurant                           portuguese, contemporary
# 11  Restaurant  mediterranean, european, portuguese, contemporary
# 12  Restaurant  seafood, mediterranean, european, portuguese, ...
# 13  Restaurant                               european, portuguese
# 14  Restaurant  international, mediterranean, european, portug...
# 15  Attraction                                                NaN
# 16  Attraction                                                NaN
# 17  Attraction                                                NaN
# 18  Attraction                                                NaN
# 19  Attraction                                                NaN
#
#                                           subcategory  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  food_drink, landmarks, attractions, classes, a...
# 16          food_drink, sightseeing_tours, activities
# 17                     shopping, museums, attractions
# 18                          wellness_spas, activities
# 19  boat_tours_water_sports, outdoor_activities, s...
#
#                                                  tags  luxury_score
# 0                                                 NaN           NaN
# 1                                                 NaN           NaN
# 2                                                 NaN           NaN
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# 5                                                 NaN           NaN
# 6                                                 NaN           NaN
# 7                                                 NaN           NaN
# 8                                                 NaN           NaN
# 9                                                 NaN           NaN
# 10                                                NaN           NaN
# 11                                                NaN           NaN
# 12                                                NaN           NaN
# 13                                                NaN           NaN
# 14                                                NaN           NaN
# 15  [food_drink, landmarks, attractions, classes, ...        45.950
# 16        [food_drink, sightseeing_tours, activities]        34.366
# 17                   [shopping, museums, attractions]        26.509
# 18                        [wellness_spas, activities]        26.253
# 19  [boat_tours_water_sports, outdoor_activities, ...        26.134

# %%
final_luxury_package.to_csv("luxury_package.csv", index=False) # Saving package as a csv file.

# %% [markdown]
# Achieved end goal for the luxury package, it contains 5 hotels for 5 nights, 10 restaurants for at least 10 meals (lunch & dinner) and 5 attractions for 5 days.
